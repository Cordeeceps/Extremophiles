# %%
from Bio import Entrez, SeqIO
from Bio.Blast import NCBIWWW
from Bio.Blast import NCBIXML
import time

# %%
# email address required to access GenBank
Entrez.email = "megzlives@gmail.com"

# %%
# function to retrieve genomic data
def retrieve_genomic_data(accession):
    print(f"Attempting to retrieve data for {accession}")
    for attempt in range(3):  # Try to fetch the data up to 3 times
        try:
            handle = Entrez.efetch(db="nucleotide", id=accession, rettype="gbwithparts", retmode="text")
            print(f"Downloading data for {accession}...")
            # Use SeqIO.parse() to read multi-sequence GenBank files
            records = list(SeqIO.parse(handle, "genbank"))
            handle.close()
            print(f"Successfully retrieved data for {accession}")
            return records  # This will be a list of records
        except Exception as e:
            print(f"An error occurred while fetching {accession}: {e}")
            print("Attempting to retry...")
            time.sleep(2)  # Wait for 2 seconds before retrying
    print(f"Failed to retrieve data for {accession} after multiple attempts.")
    return None

# %%
# sequentially retrieve genomic data for each accession number
d_radiodurans_sequences = {}
accession_numbers = [
    "NZ_CP038663.1",  # Chromosome I
    "NZ_CP038664.1",  # Chromosome II
    "NZ_CP038666.1",  # Plasmid pCP1
    "NZ_CP038665.1",  # Plasmid pMP1
]

for accession in accession_numbers:
    records = retrieve_genomic_data(accession)
    if records:
        d_radiodurans_sequences[accession] = records
        print(f"Records for {accession} added to the database.")
    else:
        print(f"Could not retrieve records for {accession}.")
# Out:
# Attempting to retrieve data for NZ_CP038663.1
# Downloading data for NZ_CP038663.1...
# Successfully retrieved data for NZ_CP038663.1
# Records for NZ_CP038663.1 added to the database.
# Attempting to retrieve data for NZ_CP038664.1
# Downloading data for NZ_CP038664.1...
# Successfully retrieved data for NZ_CP038664.1
# Records for NZ_CP038664.1 added to the database.
# Attempting to retrieve data for NZ_CP038666.1
# Downloading data for NZ_CP038666.1...
# Successfully retrieved data for NZ_CP038666.1
# Records for NZ_CP038666.1 added to the database.
# Attempting to retrieve data for NZ_CP038665.1
# Downloading data for NZ_CP038665.1...
# Successfully retrieved data for NZ_CP038665.1
# Records for NZ_CP038665.1 added to the database.

# %%
# retrieve genomic data for Thermus thermophilus
# note: this is only chromosome data, does not include pTT8 or pTT27
t_thermophilus_seq = retrieve_genomic_data("NC_006461.1")
# Out:
# Attempting to retrieve data for NC_006461.1
# Downloading data for NC_006461.1...
# Successfully retrieved data for NC_006461.1

# %%
# function to perform BLAST analysis for a gene sequence from D. radiodurans against an organism
def perform_blast(sequence, database="nt", organism="Thermus thermophilus"):
    try:
        result_handle = NCBIWWW.qblast("blastn", database, sequence, entrez_query=f'organism="{organism}"')
        return result_handle
    except Exception as e:
        print(f"Error performing BLAST: {str(e)}")
        return None

# %%
# function to parse BLAST results
def parse_blast_results(blast_result_handle):
    blast_records = NCBIXML.read(blast_result_handle)
    results = []
    for alignment in blast_records.alignments:
        for hsp in alignment.hsps:
            result = {
                'title': alignment.title,
                'score': hsp.score,
                'e_value': hsp.expect,
                'identities': hsp.identities,
                'align_length': hsp.align_length
            }
            results.append(result)
    return results

# %%
# dictionary of target genes in D. radiodurans; includes gene name and locus tags
target_genes = {
    "PprA": "E5E91_RS15025",
    "RecA": "E5E91_RS11810",
    "DdrA": "E5E91_RS02140",
    "DdrB": "E5E91_RS00360",
    "DdrC": "E5E91_RS00015",
    "NADH-quinone oxidoreductase subunit N": "E5E91_RS07520",
    "LigD": None,  # Replace with the actual locus tag when found
    "Dps": "E5E91_RS11440",
    "Bcp": None,   # Replace with the actual locus tag when found
    "IrrE": "E5E91_RS00855",
    "Ssb": None,   # Replace with the actual locus tag when found
    "PolA": "E5E91_RS08585",
    "ThyA": "E5E91_RS13290",
    "PNPase": "E5E91_RS10905"
}

# %%
# TODO: remove file writing debugging stuff 
# function for extracting gene sequence 
# change search_type to gene to search for gene name or locus_tag to search by locus tag
def extract_gene_sequence(search_term, search_type='locus_tag'):
    with open("gene_and_locus_tags.txt", "w") as file:  # Open a text file for writing
        found = False  # Flag to check if we found the gene
        for accession, records in d_radiodurans_sequences.items():
            for record in records:
                for feature in record.features:
                    if feature.type in ["gene", "CDS"]:
                        # Extract gene name, locus tag, and gene ID
                        gene_name = feature.qualifiers.get("gene", ["No gene name"])[0]
                        locus_tag = feature.qualifiers.get("locus_tag", ["No locus tag"])[0]
                        gene_id_list = feature.qualifiers.get("db_xref", [])
                        gene_id = next((id_part.split(":")[1] for id_part in gene_id_list if id_part.startswith("GeneID:")), "No Gene ID")
                        file.write(f"{gene_name}\t{locus_tag}\t{gene_id}\n")  # Write to file
                        if search_type in feature.qualifiers:
                            # This can be a list, so check if the search term is in the list
                            if search_term in feature.qualifiers[search_type]:
                                print(f"Found {search_type} {search_term} in {accession}, Record ID: {record.id}")
                                found = True
                                gene_sequence = feature.extract(record.seq)
                                return gene_sequence
                if not found:
                    print(f"Gene with {search_type} {search_term} not found in record {record.id}.")
        if not found:
            print(f"Search completed. Gene with {search_type} {search_term} not found in any of the GenBank records.")
    return None

# %%
# dictionary to store BLAST results for each gene
blast_results = {}

# %%
# extract gene sequences based on locus tag
def extract_gene_sequence(search_term, search_type='locus_tag'):
    print(f"Searching for {search_term} by {search_type}...")  # Debugging print
    for accession, records in d_radiodurans_sequences.items():
        for record in records:
            for feature in record.features:
                if feature.type in ["gene", "CDS"]:
                    # Check if search term matches the feature qualifier
                    if search_type in feature.qualifiers and search_term in feature.qualifiers[search_type]:
                        print(f"Found {search_type} {search_term} in {accession}, Record ID: {record.id}")
                        gene_sequence = feature.extract(record.seq)
                        return gene_sequence  # Make sure to return immediately after finding the sequence
            print(f"Gene with {search_type} {search_term} not found in record {record.id}.")
    print(f"Search completed. Gene with {search_type} {search_term} not found in any of the GenBank records.")
    return None

# %%
# extract gene sequences based on gene name
#for gene_name in target_genes.keys():
    #gene_sequence = extract_gene_sequence(gene_name, search_type='gene')
    #if gene_sequence:
        # Proceed with BLAST, etc.
    #else:
        #print(f"Sequence extraction failed for gene: {gene_name}")

# %%
# Perform BLAST and parse results
for gene, locus_tag in target_genes.items():
    print(f"Processing gene: {gene}")  # Debugging print
    if locus_tag:  # Make sure the locus tag is not None
        gene_sequence = extract_gene_sequence(locus_tag, search_type='locus_tag')
        if gene_sequence:
            print(f"Performing BLAST search for {gene}...")
            result_handle = perform_blast(str(gene_sequence), organism="Thermus thermophilus")
            if result_handle:
                # Parse the BLAST result handle and store it in the blast_results dictionary
                blast_results[gene] = parse_blast_results(result_handle)
                print(f"BLAST search completed for {gene}")
            else:
                print(f"BLAST search failed for gene: {gene}")
        else:
            print(f"Sequence extraction failed for gene: {gene}")
    else:
        print(f"Locus tag not found for gene: {gene}")
# Out:
# Processing gene: PprA
# Searching for E5E91_RS15025 by locus_tag...
# Gene with locus_tag E5E91_RS15025 not found in record NZ_CP038663.1.
# Found locus_tag E5E91_RS15025 in NZ_CP038664.1, Record ID: NZ_CP038664.1
# Performing BLAST search for PprA...
# BLAST search completed for PprA
# Processing gene: RecA
# Searching for E5E91_RS11810 by locus_tag...
# Found locus_tag E5E91_RS11810 in NZ_CP038663.1, Record ID: NZ_CP038663.1
# Performing BLAST search for RecA...
# BLAST search completed for RecA
# Processing gene: DdrA
# Searching for E5E91_RS02140 by locus_tag...
# Found locus_tag E5E91_RS02140 in NZ_CP038663.1, Record ID: NZ_CP038663.1
# Performing BLAST search for DdrA...
# BLAST search completed for DdrA
# Processing gene: DdrB
# Searching for E5E91_RS00360 by locus_tag...
# Found locus_tag E5E91_RS00360 in NZ_CP038663.1, Record ID: NZ_CP038663.1
# Performing BLAST search for DdrB...
# BLAST search completed for DdrB
# Processing gene: DdrC
# Searching for E5E91_RS00015 by locus_tag...
# Found locus_tag E5E91_RS00015 in NZ_CP038663.1, Record ID: NZ_CP038663.1
# Performing BLAST search for DdrC...
# BLAST search completed for DdrC
# Processing gene: NADH-quinone oxidoreductase subunit N
# Searching for E5E91_RS07520 by locus_tag...
# Found locus_tag E5E91_RS07520 in NZ_CP038663.1, Record ID: NZ_CP038663.1
# Performing BLAST search for NADH-quinone oxidoreductase subunit N...
# BLAST search completed for NADH-quinone oxidoreductase subunit N
# Processing gene: LigD
# Locus tag not found for gene: LigD
# Processing gene: Dps
# Searching for E5E91_RS11440 by locus_tag...
# Found locus_tag E5E91_RS11440 in NZ_CP038663.1, Record ID: NZ_CP038663.1
# Performing BLAST search for Dps...
# BLAST search completed for Dps
# Processing gene: Bcp
# Locus tag not found for gene: Bcp
# Processing gene: IrrE
# Searching for E5E91_RS00855 by locus_tag...
# Found locus_tag E5E91_RS00855 in NZ_CP038663.1, Record ID: NZ_CP038663.1
# Performing BLAST search for IrrE...
# BLAST search completed for IrrE
# Processing gene: Ssb
# Locus tag not found for gene: Ssb
# Processing gene: PolA
# Searching for E5E91_RS08585 by locus_tag...
# Found locus_tag E5E91_RS08585 in NZ_CP038663.1, Record ID: NZ_CP038663.1
# Performing BLAST search for PolA...
# Error performing BLAST: <urlopen error [WinError 10051] A socket operation was attempted to an unreachable network>
# BLAST search failed for gene: PolA
# Processing gene: ThyA
# Searching for E5E91_RS13290 by locus_tag...
# Found locus_tag E5E91_RS13290 in NZ_CP038663.1, Record ID: NZ_CP038663.1
# Performing BLAST search for ThyA...
# BLAST search completed for ThyA
# Processing gene: PNPase
# Searching for E5E91_RS10905 by locus_tag...
# Found locus_tag E5E91_RS10905 in NZ_CP038663.1, Record ID: NZ_CP038663.1
# Performing BLAST search for PNPase...
# BLAST search completed for PNPase

# %%
# Function to display BLAST results
def display_blast_results(blast_results):
    for gene, results in blast_results.items():
        print(f"Results for {gene}:")
        for result in results:
            print(f"Title: {result['title']}")
            print(f"Score: {result['score']}")
            print(f"E-value: {result['e_value']}")
            print(f"Identities: {result['identities']}")
            print(f"Alignment length: {result['align_length']}")
            print("\n")

# %%
# Now display the BLAST results
print("BLAST results keys:", blast_results.keys())
display_blast_results(blast_results)
# Out:
# BLAST results keys: dict_keys(['PprA', 'RecA', 'DdrA', 'DdrB', 'DdrC', 'NADH-quinone oxidoreductase subunit N', 'Dps', 'IrrE', 'ThyA', 'PNPase'])
# Results for PprA:
# Title: gi|1012291606|gb|CP014867.1| Pseudomonas chlororaphis isolate 189, complete genome
# Score: 52.0
# E-value: 0.0108898
# Identities: 43
# Alignment length: 53
#
#
# Title: gi|1012291606|gb|CP014867.1| Pseudomonas chlororaphis isolate 189, complete genome
# Score: 44.0
# E-value: 1.6162
# Identities: 22
# Alignment length: 22
#
#
# Title: gi|1012291606|gb|CP014867.1| Pseudomonas chlororaphis isolate 189, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 31
# Alignment length: 37
#
#
# Title: gi|758845968|gb|CP010892.1| Pseudomonas sp. MRSN12121, complete genome
# Score: 52.0
# E-value: 0.0108898
# Identities: 46
# Alignment length: 58
#
#
# Title: gi|758845968|gb|CP010892.1| Pseudomonas sp. MRSN12121, complete genome
# Score: 47.0
# E-value: 0.463048
# Identities: 38
# Alignment length: 45
#
#
# Title: gi|758845968|gb|CP010892.1| Pseudomonas sp. MRSN12121, complete genome
# Score: 44.0
# E-value: 1.6162
# Identities: 22
# Alignment length: 22
#
#
# Title: gi|758845968|gb|CP010892.1| Pseudomonas sp. MRSN12121, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 31
# Alignment length: 37
#
#
# Title: gi|647802220|gb|CP008696.1| Pseudomonas chlororaphis strain PA23, complete genome
# Score: 50.0
# E-value: 0.0380093
# Identities: 45
# Alignment length: 57
#
#
# Title: gi|647802220|gb|CP008696.1| Pseudomonas chlororaphis strain PA23, complete genome
# Score: 44.0
# E-value: 1.6162
# Identities: 22
# Alignment length: 22
#
#
# Title: gi|647802220|gb|CP008696.1| Pseudomonas chlororaphis strain PA23, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 31
# Alignment length: 37
#
#
# Title: gi|1066925896|gb|CP011972.2| Pseudomonas syringae pv. actinidiae ICMP 18884, complete genome
# Score: 49.0
# E-value: 0.132665
# Identities: 29
# Alignment length: 32
#
#
# Title: gi|1057920376|gb|CP012179.1| Pseudomonas syringae pv. actinidiae ICMP 18708, complete genome
# Score: 49.0
# E-value: 0.132665
# Identities: 29
# Alignment length: 32
#
#
# Title: gi|927283541|gb|CP005970.1| Pseudomonas syringae UMAF0158, complete genome
# Score: 49.0
# E-value: 0.132665
# Identities: 46
# Alignment length: 59
#
#
# Title: gi|927283541|gb|CP005970.1| Pseudomonas syringae UMAF0158, complete genome
# Score: 46.0
# E-value: 0.463048
# Identities: 29
# Alignment length: 33
#
#
# Title: gi|984703981|gb|CP013861.1| Pseudomonas fragi strain P121 chromosome, complete genome
# Score: 48.0
# E-value: 0.132665
# Identities: 35
# Alignment length: 41
#
#
# Title: gi|1021079766|dbj|AP017424.1| Streptomyces laurentii DNA, complete genome, strain: ATCC 31255
# Score: 47.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 38
#
#
# Title: gi|1021079766|dbj|AP017424.1| Streptomyces laurentii DNA, complete genome, strain: ATCC 31255
# Score: 46.0
# E-value: 0.463048
# Identities: 34
# Alignment length: 40
#
#
# Title: gi|1021079766|dbj|AP017424.1| Streptomyces laurentii DNA, complete genome, strain: ATCC 31255
# Score: 45.0
# E-value: 1.6162
# Identities: 27
# Alignment length: 30
#
#
# Title: gi|1021079766|dbj|AP017424.1| Streptomyces laurentii DNA, complete genome, strain: ATCC 31255
# Score: 44.0
# E-value: 1.6162
# Identities: 32
# Alignment length: 38
#
#
# Title: gi|1021079766|dbj|AP017424.1| Streptomyces laurentii DNA, complete genome, strain: ATCC 31255
# Score: 43.0
# E-value: 5.64108
# Identities: 35
# Alignment length: 44
#
#
# Title: gi|1021079766|dbj|AP017424.1| Streptomyces laurentii DNA, complete genome, strain: ATCC 31255
# Score: 43.0
# E-value: 5.64108
# Identities: 23
# Alignment length: 24
#
#
# Title: gi|807234606|gb|CP011256.1| Xanthomonas arboricola strain 17, complete genome
# Score: 47.0
# E-value: 0.463048
# Identities: 28
# Alignment length: 31
#
#
# Title: gi|807234606|gb|CP011256.1| Xanthomonas arboricola strain 17, complete genome
# Score: 44.0
# E-value: 1.6162
# Identities: 42
# Alignment length: 54
#
#
# Title: gi|692342259|gb|CP009533.1| Pseudomonas rhizosphaerae strain DSM 16299, complete genome
# Score: 47.0
# E-value: 0.463048
# Identities: 31
# Alignment length: 35
#
#
# Title: gi|692336178|gb|CP009290.1| Pseudomonas chlororaphis subsp. aurantiaca strain JD37, complete genome
# Score: 47.0
# E-value: 0.463048
# Identities: 42
# Alignment length: 53
#
#
# Title: gi|692336178|gb|CP009290.1| Pseudomonas chlororaphis subsp. aurantiaca strain JD37, complete genome
# Score: 44.0
# E-value: 1.6162
# Identities: 22
# Alignment length: 22
#
#
# Title: gi|692336178|gb|CP009290.1| Pseudomonas chlororaphis subsp. aurantiaca strain JD37, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 31
# Alignment length: 37
#
#
# Title: gi|1044517319|gb|CP016380.1| Aeromonas hydrophila strain AHNIH1, complete genome
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|1044517319|gb|CP016380.1| Aeromonas hydrophila strain AHNIH1, complete genome
# Score: 43.0
# E-value: 5.64108
# Identities: 26
# Alignment length: 29
#
#
# Title: gi|975025465|gb|CP013965.1| Aeromonas hydrophila strain D4 chromosome, complete genome
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|973430823|gb|CP007518.2| Aeromonas hydrophila YL17, complete genome
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|970580326|gb|CP013183.1| Pseudomonas syringae pv. lapsa strain ATCC 10859 chromosome, complete genome
# Score: 46.0
# E-value: 0.463048
# Identities: 29
# Alignment length: 33
#
#
# Title: gi|958617326|gb|CP013178.1| Aeromonas hydrophila strain JBN2301 chromosome, complete genome
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|827370414|gb|CP006870.1| Aeromonas hydrophila NJ-35, complete genome
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|785807861|gb|CP011100.1| Aeromonas hydrophila strain AH10, complete genome
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|785807861|gb|CP011100.1| Aeromonas hydrophila strain AH10, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 27
# Alignment length: 31
#
#
# Title: gi|764079125|gb|CP010947.1| Aeromonas hydrophila strain AL06-06, complete genome
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|764079125|gb|CP010947.1| Aeromonas hydrophila strain AL06-06, complete genome
# Score: 43.0
# E-value: 5.64108
# Identities: 26
# Alignment length: 29
#
#
# Title: gi|748231934|gb|CP006883.1| Aeromonas hydrophila J-1, complete genome
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265458965|emb|LR963141.1| Aeromonas hydrophila isolate T4 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265454226|emb|LR963138.1| Aeromonas hydrophila strain vAh ST251 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265449258|emb|LR963135.1| Aeromonas hydrophila strain vAh ST251 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265444577|emb|LR963132.1| Aeromonas hydrophila strain vAh ST251 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265439653|emb|LR963129.1| Aeromonas hydrophila strain vAh ST251 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265434934|emb|LR963127.1| Aeromonas hydrophila strain vAh ST251 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265430172|emb|LR963122.1| Aeromonas dhakensis isolate TN4 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265430172|emb|LR963122.1| Aeromonas dhakensis isolate TN4 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 5.64108
# Identities: 32
# Alignment length: 39
#
#
# Title: gi|2265425554|emb|LR963117.1| Aeromonas dhakensis isolate TN5 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265425554|emb|LR963117.1| Aeromonas dhakensis isolate TN5 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 5.64108
# Identities: 32
# Alignment length: 39
#
#
# Title: gi|2265420415|emb|LR963112.1| Aeromonas dhakensis isolate TN3 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265420415|emb|LR963112.1| Aeromonas dhakensis isolate TN3 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 5.64108
# Identities: 32
# Alignment length: 39
#
#
# Title: gi|2265415584|emb|LR963107.1| Aeromonas dhakensis isolate TN49 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265415584|emb|LR963107.1| Aeromonas dhakensis isolate TN49 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 5.64108
# Identities: 32
# Alignment length: 39
#
#
# Title: gi|2265410592|emb|LR963104.1| Aeromonas dhakensis isolate TN14 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265410592|emb|LR963104.1| Aeromonas dhakensis isolate TN14 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 5.64108
# Identities: 32
# Alignment length: 39
#
#
# Title: gi|2265405416|emb|LR963099.1| Aeromonas dhakensis isolate TN10 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265405416|emb|LR963099.1| Aeromonas dhakensis isolate TN10 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 5.64108
# Identities: 32
# Alignment length: 39
#
#
# Title: gi|2265400372|emb|LR963094.1| Aeromonas dhakensis isolate TN50 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265400372|emb|LR963094.1| Aeromonas dhakensis isolate TN50 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 5.64108
# Identities: 32
# Alignment length: 39
#
#
# Title: gi|2265395661|emb|LR963089.1| Aeromonas dhakensis isolate TN11 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265395661|emb|LR963089.1| Aeromonas dhakensis isolate TN11 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 5.64108
# Identities: 32
# Alignment length: 39
#
#
# Title: gi|2265390828|emb|LR963084.1| Aeromonas dhakensis isolate TN59 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265390828|emb|LR963084.1| Aeromonas dhakensis isolate TN59 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 5.64108
# Identities: 32
# Alignment length: 39
#
#
# Title: gi|2265386260|emb|LR963079.1| Aeromonas dhakensis isolate TN45 genome assembly, chromosome: 1
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|2265386260|emb|LR963079.1| Aeromonas dhakensis isolate TN45 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 5.64108
# Identities: 32
# Alignment length: 39
#
#
# Title: gi|615567765|gb|CP007576.1| Aeromonas hydrophila pc104A, complete genome
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|613730844|gb|CP007566.1| Aeromonas hydrophila AL09-71, complete genome
# Score: 46.0
# E-value: 0.463048
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|591390487|gb|CP007410.1| Pseudomonas brassicacearum strain DF41, complete genome
# Score: 46.0
# E-value: 0.463048
# Identities: 37
# Alignment length: 45
#
#
# Title: gi|591390487|gb|CP007410.1| Pseudomonas brassicacearum strain DF41, complete genome
# Score: 45.0
# E-value: 1.6162
# Identities: 35
# Alignment length: 42
#
#
# Title: gi|591390487|gb|CP007410.1| Pseudomonas brassicacearum strain DF41, complete genome
# Score: 44.0
# E-value: 1.6162
# Identities: 22
# Alignment length: 22
#
#
# Title: gi|591390487|gb|CP007410.1| Pseudomonas brassicacearum strain DF41, complete genome
# Score: 43.0
# E-value: 5.64108
# Identities: 26
# Alignment length: 29
#
#
# Title: gi|570731247|gb|CP007031.1| Marichromatium purpuratum 984, complete genome
# Score: 46.0
# E-value: 0.463048
# Identities: 38
# Alignment length: 46
#
#
# Title: gi|1169601839|gb|CP014866.1| Pseudomonas aeruginosa strain PA_154197 chromosome, complete genome
# Score: 45.0
# E-value: 1.6162
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|1169601839|gb|CP014866.1| Pseudomonas aeruginosa strain PA_154197 chromosome, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 27
# Alignment length: 31
#
#
# Title: gi|1169601839|gb|CP014866.1| Pseudomonas aeruginosa strain PA_154197 chromosome, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 35
# Alignment length: 43
#
#
# Title: gi|1133639402|emb|LT708304.1| Mycobacterium bovis AF2122/97 genome assembly, chromosome: Mycobacterium_bovis_AF212297
# Score: 45.0
# E-value: 1.6162
# Identities: 24
# Alignment length: 25
#
#
# Title: gi|1133639402|emb|LT708304.1| Mycobacterium bovis AF2122/97 genome assembly, chromosome: Mycobacterium_bovis_AF212297
# Score: 43.0
# E-value: 5.64108
# Identities: 54
# Alignment length: 72
#
#
# Title: gi|1133639402|emb|LT708304.1| Mycobacterium bovis AF2122/97 genome assembly, chromosome: Mycobacterium_bovis_AF212297
# Score: 42.0
# E-value: 5.64108
# Identities: 24
# Alignment length: 26
#
#
# Title: gi|1044641851|gb|CP011857.1| Pseudomonas aeruginosa strain ATCC 27853, complete genome
# Score: 45.0
# E-value: 1.6162
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|1044641851|gb|CP011857.1| Pseudomonas aeruginosa strain ATCC 27853, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 27
# Alignment length: 31
#
#
# Title: gi|1021448326|gb|CP014963.1| Geobacter anodireducens strain SD-1 chromosome, complete genome
# Score: 45.0
# E-value: 1.6162
# Identities: 40
# Alignment length: 52
#
#
# Title: gi|1016892938|gb|CP015117.1| Pseudomonas aeruginosa strain ATCC 27853 chromosome, complete genome
# Score: 45.0
# E-value: 1.6162
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|1016892938|gb|CP015117.1| Pseudomonas aeruginosa strain ATCC 27853 chromosome, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 27
# Alignment length: 31
#
#
# Title: gi|982189197|gb|CP013993.1| Pseudomonas aeruginosa DHS01 chromosome, complete genome
# Score: 45.0
# E-value: 1.6162
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|982189197|gb|CP013993.1| Pseudomonas aeruginosa DHS01 chromosome, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 27
# Alignment length: 31
#
#
# Title: gi|975043142|gb|CP013989.1| Pseudomonas aeruginosa strain USDA-ARS-USMARC-41639 chromosome, complete genome
# Score: 45.0
# E-value: 1.6162
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|975043142|gb|CP013989.1| Pseudomonas aeruginosa strain USDA-ARS-USMARC-41639 chromosome, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 27
# Alignment length: 31
#
#
# Title: gi|975043142|gb|CP013989.1| Pseudomonas aeruginosa strain USDA-ARS-USMARC-41639 chromosome, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 35
# Alignment length: 43
#
#
# Title: gi|974341323|gb|CP008868.1| Pseudomonas aeruginosa strain T63266 chromosome, complete genome
# Score: 45.0
# E-value: 1.6162
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|974341323|gb|CP008868.1| Pseudomonas aeruginosa strain T63266 chromosome, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 27
# Alignment length: 31
#
#
# Title: gi|974335511|gb|CP008867.1| Pseudomonas aeruginosa strain T52373 chromosome, complete genome
# Score: 45.0
# E-value: 1.6162
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|974335511|gb|CP008867.1| Pseudomonas aeruginosa strain T52373 chromosome, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 27
# Alignment length: 31
#
#
# Title: gi|974311447|gb|CP008863.1| Pseudomonas aeruginosa strain M37351 chromosome, complete genome
# Score: 45.0
# E-value: 1.6162
# Identities: 33
# Alignment length: 39
#
#
# Title: gi|974311447|gb|CP008863.1| Pseudomonas aeruginosa strain M37351 chromosome, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 35
# Alignment length: 43
#
#
# Title: gi|974311447|gb|CP008863.1| Pseudomonas aeruginosa strain M37351 chromosome, complete genome
# Score: 42.0
# E-value: 5.64108
# Identities: 27
# Alignment length: 31
#
#
# Results for RecA:
# Title: gi|410696020|gb|CP003249.1| Thermus oshimai JL-2, complete genome
# Score: 597.0
# E-value: 2.89642e-150
# Identities: 670
# Alignment length: 915
#
#
# Title: gi|410696020|gb|CP003249.1| Thermus oshimai JL-2, complete genome
# Score: 43.0
# E-value: 6.86003
# Identities: 40
# Alignment length: 51
#
#
# Title: gi|410696020|gb|CP003249.1| Thermus oshimai JL-2, complete genome
# Score: 43.0
# E-value: 6.86003
# Identities: 23
# Alignment length: 24
#
#
# Title: gi|410696020|gb|CP003249.1| Thermus oshimai JL-2, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 21
# Alignment length: 21
#
#
# Title: gi|1105531595|dbj|AP017920.1| Thermus thermophilus DNA, complete genome, strain: TMY
# Score: 577.0
# E-value: 7.77218e-145
# Identities: 661
# Alignment length: 901
#
#
# Title: gi|1105531595|dbj|AP017920.1| Thermus thermophilus DNA, complete genome, strain: TMY
# Score: 48.0
# E-value: 0.161332
# Identities: 41
# Alignment length: 51
#
#
# Title: gi|1105531595|dbj|AP017920.1| Thermus thermophilus DNA, complete genome, strain: TMY
# Score: 43.0
# E-value: 6.86003
# Identities: 35
# Alignment length: 44
#
#
# Title: gi|383508497|gb|CP003252.1| Thermus thermophilus JL-18, complete genome
# Score: 570.0
# E-value: 3.30481e-143
# Identities: 656
# Alignment length: 898
#
#
# Title: gi|383508497|gb|CP003252.1| Thermus thermophilus JL-18, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 41
# Alignment length: 51
#
#
# Title: gi|383508497|gb|CP003252.1| Thermus thermophilus JL-18, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 24
# Alignment length: 26
#
#
# Title: gi|333965676|gb|CP002777.1| Thermus thermophilus SG0.5JP17-16, complete genome
# Score: 565.0
# E-value: 1.40524e-141
# Identities: 655
# Alignment length: 898
#
#
# Title: gi|333965676|gb|CP002777.1| Thermus thermophilus SG0.5JP17-16, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 41
# Alignment length: 51
#
#
# Title: gi|333965676|gb|CP002777.1| Thermus thermophilus SG0.5JP17-16, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 24
# Alignment length: 26
#
#
# Title: gi|333965676|gb|CP002777.1| Thermus thermophilus SG0.5JP17-16, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|119668705|emb|AM406670.1| Azoarcus olearius strain BH72 genome assembly
# Score: 520.0
# E-value: 1.23268e-129
# Identities: 647
# Alignment length: 895
#
#
# Title: gi|933519261|gb|CP012401.1| Azospirillum thiophilum strain BV-S chromosome 1, complete sequence
# Score: 517.0
# E-value: 1.50171e-128
# Identities: 577
# Alignment length: 776
#
#
# Title: gi|933519261|gb|CP012401.1| Azospirillum thiophilum strain BV-S chromosome 1, complete sequence
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|933519261|gb|CP012401.1| Azospirillum thiophilum strain BV-S chromosome 1, complete sequence
# Score: 44.0
# E-value: 1.96543
# Identities: 31
# Alignment length: 37
#
#
# Title: gi|933519261|gb|CP012401.1| Azospirillum thiophilum strain BV-S chromosome 1, complete sequence
# Score: 43.0
# E-value: 6.86003
# Identities: 31
# Alignment length: 36
#
#
# Title: gi|1021448326|gb|CP014963.1| Geobacter anodireducens strain SD-1 chromosome, complete genome
# Score: 493.0
# E-value: 4.90911e-122
# Identities: 675
# Alignment length: 956
#
#
# Title: gi|1021448326|gb|CP014963.1| Geobacter anodireducens strain SD-1 chromosome, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 46
# Alignment length: 61
#
#
# Title: gi|1021448326|gb|CP014963.1| Geobacter anodireducens strain SD-1 chromosome, complete genome
# Score: 43.0
# E-value: 6.86003
# Identities: 23
# Alignment length: 24
#
#
# Title: gi|938485835|gb|CP012914.1| Azospirillum brasilense strain Sp 7 chromosome, complete sequence
# Score: 492.0
# E-value: 4.90911e-122
# Identities: 549
# Alignment length: 737
#
#
# Title: gi|938485835|gb|CP012914.1| Azospirillum brasilense strain Sp 7 chromosome, complete sequence
# Score: 43.0
# E-value: 6.86003
# Identities: 29
# Alignment length: 34
#
#
# Title: gi|938485835|gb|CP012914.1| Azospirillum brasilense strain Sp 7 chromosome, complete sequence
# Score: 42.0
# E-value: 6.86003
# Identities: 24
# Alignment length: 26
#
#
# Title: gi|938485835|gb|CP012914.1| Azospirillum brasilense strain Sp 7 chromosome, complete sequence
# Score: 42.0
# E-value: 6.86003
# Identities: 30
# Alignment length: 36
#
#
# Title: gi|646255953|gb|CP007793.1| Azospirillum brasilense strain Az39, complete genome
# Score: 469.0
# E-value: 1.6048e-115
# Identities: 482
# Alignment length: 639
#
#
# Title: gi|646255953|gb|CP007793.1| Azospirillum brasilense strain Az39, complete genome
# Score: 43.0
# E-value: 6.86003
# Identities: 29
# Alignment length: 34
#
#
# Title: gi|646255953|gb|CP007793.1| Azospirillum brasilense strain Az39, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 24
# Alignment length: 26
#
#
# Title: gi|1022528561|gb|CP015377.1| Pseudomonas aeruginosa strain BAMCPA07-48 chromosome, complete genome
# Score: 467.0
# E-value: 5.60129e-115
# Identities: 634
# Alignment length: 888
#
#
# Title: gi|1022528561|gb|CP015377.1| Pseudomonas aeruginosa strain BAMCPA07-48 chromosome, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|1022528561|gb|CP015377.1| Pseudomonas aeruginosa strain BAMCPA07-48 chromosome, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|1022528561|gb|CP015377.1| Pseudomonas aeruginosa strain BAMCPA07-48 chromosome, complete genome
# Score: 44.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 34
#
#
# Title: gi|1022528561|gb|CP015377.1| Pseudomonas aeruginosa strain BAMCPA07-48 chromosome, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|1847250123|dbj|AP022810.1| Desulfuromonas sp. AOP6 DNA, complete genome
# Score: 466.0
# E-value: 5.60129e-115
# Identities: 625
# Alignment length: 881
#
#
# Title: gi|1021079766|dbj|AP017424.1| Streptomyces laurentii DNA, complete genome, strain: ATCC 31255
# Score: 466.0
# E-value: 5.60129e-115
# Identities: 569
# Alignment length: 783
#
#
# Title: gi|1021079766|dbj|AP017424.1| Streptomyces laurentii DNA, complete genome, strain: ATCC 31255
# Score: 46.0
# E-value: 0.563106
# Identities: 29
# Alignment length: 33
#
#
# Title: gi|1021079766|dbj|AP017424.1| Streptomyces laurentii DNA, complete genome, strain: ATCC 31255
# Score: 45.0
# E-value: 1.96543
# Identities: 37
# Alignment length: 46
#
#
# Title: gi|1021079766|dbj|AP017424.1| Streptomyces laurentii DNA, complete genome, strain: ATCC 31255
# Score: 45.0
# E-value: 1.96543
# Identities: 27
# Alignment length: 30
#
#
# Title: gi|1021079766|dbj|AP017424.1| Streptomyces laurentii DNA, complete genome, strain: ATCC 31255
# Score: 43.0
# E-value: 6.86003
# Identities: 35
# Alignment length: 44
#
#
# Title: gi|1021079766|dbj|AP017424.1| Streptomyces laurentii DNA, complete genome, strain: ATCC 31255
# Score: 42.0
# E-value: 6.86003
# Identities: 21
# Alignment length: 21
#
#
# Title: gi|1021079766|dbj|AP017424.1| Streptomyces laurentii DNA, complete genome, strain: ATCC 31255
# Score: 42.0
# E-value: 6.86003
# Identities: 24
# Alignment length: 26
#
#
# Title: gi|1044641851|gb|CP011857.1| Pseudomonas aeruginosa strain ATCC 27853, complete genome
# Score: 463.0
# E-value: 6.82377e-114
# Identities: 632
# Alignment length: 887
#
#
# Title: gi|1044641851|gb|CP011857.1| Pseudomonas aeruginosa strain ATCC 27853, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|1044641851|gb|CP011857.1| Pseudomonas aeruginosa strain ATCC 27853, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|1044641851|gb|CP011857.1| Pseudomonas aeruginosa strain ATCC 27853, complete genome
# Score: 44.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 34
#
#
# Title: gi|1044641851|gb|CP011857.1| Pseudomonas aeruginosa strain ATCC 27853, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|1016892938|gb|CP015117.1| Pseudomonas aeruginosa strain ATCC 27853 chromosome, complete genome
# Score: 463.0
# E-value: 6.82377e-114
# Identities: 632
# Alignment length: 887
#
#
# Title: gi|1016892938|gb|CP015117.1| Pseudomonas aeruginosa strain ATCC 27853 chromosome, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|1016892938|gb|CP015117.1| Pseudomonas aeruginosa strain ATCC 27853 chromosome, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|1016892938|gb|CP015117.1| Pseudomonas aeruginosa strain ATCC 27853 chromosome, complete genome
# Score: 44.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 34
#
#
# Title: gi|1016892938|gb|CP015117.1| Pseudomonas aeruginosa strain ATCC 27853 chromosome, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|974311447|gb|CP008863.1| Pseudomonas aeruginosa strain M37351 chromosome, complete genome
# Score: 463.0
# E-value: 6.82377e-114
# Identities: 632
# Alignment length: 887
#
#
# Title: gi|974311447|gb|CP008863.1| Pseudomonas aeruginosa strain M37351 chromosome, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|974311447|gb|CP008863.1| Pseudomonas aeruginosa strain M37351 chromosome, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|974311447|gb|CP008863.1| Pseudomonas aeruginosa strain M37351 chromosome, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|817624209|gb|CP011369.1| Pseudomonas aeruginosa strain S04 90 chromosome
# Score: 463.0
# E-value: 6.82377e-114
# Identities: 632
# Alignment length: 887
#
#
# Title: gi|817624209|gb|CP011369.1| Pseudomonas aeruginosa strain S04 90 chromosome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|817624209|gb|CP011369.1| Pseudomonas aeruginosa strain S04 90 chromosome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|817624209|gb|CP011369.1| Pseudomonas aeruginosa strain S04 90 chromosome
# Score: 44.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 34
#
#
# Title: gi|817624209|gb|CP011369.1| Pseudomonas aeruginosa strain S04 90 chromosome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|974341323|gb|CP008868.1| Pseudomonas aeruginosa strain T63266 chromosome, complete genome
# Score: 458.0
# E-value: 8.31306e-113
# Identities: 631
# Alignment length: 887
#
#
# Title: gi|974341323|gb|CP008868.1| Pseudomonas aeruginosa strain T63266 chromosome, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|974341323|gb|CP008868.1| Pseudomonas aeruginosa strain T63266 chromosome, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|974341323|gb|CP008868.1| Pseudomonas aeruginosa strain T63266 chromosome, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|974341323|gb|CP008868.1| Pseudomonas aeruginosa strain T63266 chromosome, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 21
# Alignment length: 21
#
#
# Title: gi|974335511|gb|CP008867.1| Pseudomonas aeruginosa strain T52373 chromosome, complete genome
# Score: 458.0
# E-value: 8.31306e-113
# Identities: 631
# Alignment length: 887
#
#
# Title: gi|974335511|gb|CP008867.1| Pseudomonas aeruginosa strain T52373 chromosome, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|974335511|gb|CP008867.1| Pseudomonas aeruginosa strain T52373 chromosome, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|974335511|gb|CP008867.1| Pseudomonas aeruginosa strain T52373 chromosome, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|881079720|gb|CP012066.1| Pseudomonas aeruginosa strain F9676, complete genome
# Score: 458.0
# E-value: 8.31306e-113
# Identities: 631
# Alignment length: 887
#
#
# Title: gi|881079720|gb|CP012066.1| Pseudomonas aeruginosa strain F9676, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|881079720|gb|CP012066.1| Pseudomonas aeruginosa strain F9676, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|745838743|gb|CP007399.1| Pseudomonas aeruginosa strain F22031, complete genome
# Score: 458.0
# E-value: 8.31306e-113
# Identities: 631
# Alignment length: 887
#
#
# Title: gi|745838743|gb|CP007399.1| Pseudomonas aeruginosa strain F22031, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|745838743|gb|CP007399.1| Pseudomonas aeruginosa strain F22031, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|745838743|gb|CP007399.1| Pseudomonas aeruginosa strain F22031, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|674252391|gb|CP008739.2| Pseudomonas aeruginosa VRFPA04, complete genome
# Score: 458.0
# E-value: 8.31306e-113
# Identities: 631
# Alignment length: 887
#
#
# Title: gi|674252391|gb|CP008739.2| Pseudomonas aeruginosa VRFPA04, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|674252391|gb|CP008739.2| Pseudomonas aeruginosa VRFPA04, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|674252391|gb|CP008739.2| Pseudomonas aeruginosa VRFPA04, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|563408818|gb|CP006853.1| Pseudomonas aeruginosa MTB-1, complete genome
# Score: 458.0
# E-value: 8.31306e-113
# Identities: 631
# Alignment length: 887
#
#
# Title: gi|563408818|gb|CP006853.1| Pseudomonas aeruginosa MTB-1, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|563408818|gb|CP006853.1| Pseudomonas aeruginosa MTB-1, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|563408818|gb|CP006853.1| Pseudomonas aeruginosa MTB-1, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|1169601839|gb|CP014866.1| Pseudomonas aeruginosa strain PA_154197 chromosome, complete genome
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|1169601839|gb|CP014866.1| Pseudomonas aeruginosa strain PA_154197 chromosome, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|1169601839|gb|CP014866.1| Pseudomonas aeruginosa strain PA_154197 chromosome, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|1169601839|gb|CP014866.1| Pseudomonas aeruginosa strain PA_154197 chromosome, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|974282928|gb|CP008861.1| Pseudomonas aeruginosa strain H47921 chromosome, complete genome
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|974282928|gb|CP008861.1| Pseudomonas aeruginosa strain H47921 chromosome, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|974282928|gb|CP008861.1| Pseudomonas aeruginosa strain H47921 chromosome, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|974282928|gb|CP008861.1| Pseudomonas aeruginosa strain H47921 chromosome, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|974282928|gb|CP008861.1| Pseudomonas aeruginosa strain H47921 chromosome, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 21
# Alignment length: 21
#
#
# Title: gi|974255378|gb|CP008857.1| Pseudomonas aeruginosa strain F30658 chromosome, complete genome
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|974255378|gb|CP008857.1| Pseudomonas aeruginosa strain F30658 chromosome, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|974255378|gb|CP008857.1| Pseudomonas aeruginosa strain F30658 chromosome, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|974255378|gb|CP008857.1| Pseudomonas aeruginosa strain F30658 chromosome, complete genome
# Score: 44.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 34
#
#
# Title: gi|974255378|gb|CP008857.1| Pseudomonas aeruginosa strain F30658 chromosome, complete genome
# Score: 44.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 34
#
#
# Title: gi|974255378|gb|CP008857.1| Pseudomonas aeruginosa strain F30658 chromosome, complete genome
# Score: 44.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 34
#
#
# Title: gi|970332569|gb|CP013696.1| Pseudomonas aeruginosa strain 12-4-4(59) chromosome, complete genome
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|970332569|gb|CP013696.1| Pseudomonas aeruginosa strain 12-4-4(59) chromosome, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|970332569|gb|CP013696.1| Pseudomonas aeruginosa strain 12-4-4(59) chromosome, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|927993303|gb|CP012679.1| Pseudomonas aeruginosa strain PA1RG chromosome, complete genome
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|927993303|gb|CP012679.1| Pseudomonas aeruginosa strain PA1RG chromosome, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|927993303|gb|CP012679.1| Pseudomonas aeruginosa strain PA1RG chromosome, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|927993303|gb|CP012679.1| Pseudomonas aeruginosa strain PA1RG chromosome, complete genome
# Score: 45.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 35
#
#
# Title: gi|927993303|gb|CP012679.1| Pseudomonas aeruginosa strain PA1RG chromosome, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|927226644|gb|CP004054.2| Pseudomonas aeruginosa PA1, complete genome
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|927226644|gb|CP004054.2| Pseudomonas aeruginosa PA1, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|927226644|gb|CP004054.2| Pseudomonas aeruginosa PA1, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|927226644|gb|CP004054.2| Pseudomonas aeruginosa PA1, complete genome
# Score: 45.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 35
#
#
# Title: gi|927226644|gb|CP004054.2| Pseudomonas aeruginosa PA1, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|861670927|gb|CP012001.1| Pseudomonas aeruginosa DSM 50071, complete genome
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|861670927|gb|CP012001.1| Pseudomonas aeruginosa DSM 50071, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|861670927|gb|CP012001.1| Pseudomonas aeruginosa DSM 50071, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|861670927|gb|CP012001.1| Pseudomonas aeruginosa DSM 50071, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|815968487|gb|CP011317.1| Pseudomonas aeruginosa strain Carb01 63, complete genome
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|815968487|gb|CP011317.1| Pseudomonas aeruginosa strain Carb01 63, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|815968487|gb|CP011317.1| Pseudomonas aeruginosa strain Carb01 63, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|751373101|gb|CP010555.1| Pseudomonas aeruginosa strain FRD1, complete genome
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|751373101|gb|CP010555.1| Pseudomonas aeruginosa strain FRD1, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|751373101|gb|CP010555.1| Pseudomonas aeruginosa strain FRD1, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|589338112|gb|CP006985.1| Pseudomonas aeruginosa LESlike4 sequence
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|589338112|gb|CP006985.1| Pseudomonas aeruginosa LESlike4 sequence
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|589338112|gb|CP006985.1| Pseudomonas aeruginosa LESlike4 sequence
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|589338112|gb|CP006985.1| Pseudomonas aeruginosa LESlike4 sequence
# Score: 44.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 34
#
#
# Title: gi|589338112|gb|CP006985.1| Pseudomonas aeruginosa LESlike4 sequence
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|589338112|gb|CP006985.1| Pseudomonas aeruginosa LESlike4 sequence
# Score: 42.0
# E-value: 6.86003
# Identities: 27
# Alignment length: 31
#
#
# Title: gi|589332184|gb|CP006984.1| Pseudomonas aeruginosa LESlike1 chromosome
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|589332184|gb|CP006984.1| Pseudomonas aeruginosa LESlike1 chromosome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|589332184|gb|CP006984.1| Pseudomonas aeruginosa LESlike1 chromosome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|589332184|gb|CP006984.1| Pseudomonas aeruginosa LESlike1 chromosome
# Score: 44.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 34
#
#
# Title: gi|589332184|gb|CP006984.1| Pseudomonas aeruginosa LESlike1 chromosome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|589332184|gb|CP006984.1| Pseudomonas aeruginosa LESlike1 chromosome
# Score: 42.0
# E-value: 6.86003
# Identities: 27
# Alignment length: 31
#
#
# Title: gi|589326231|gb|CP006983.1| Pseudomonas aeruginosa LESB65 sequence
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|589326231|gb|CP006983.1| Pseudomonas aeruginosa LESB65 sequence
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|589326231|gb|CP006983.1| Pseudomonas aeruginosa LESB65 sequence
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|589326231|gb|CP006983.1| Pseudomonas aeruginosa LESB65 sequence
# Score: 44.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 34
#
#
# Title: gi|589326231|gb|CP006983.1| Pseudomonas aeruginosa LESB65 sequence
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|589326231|gb|CP006983.1| Pseudomonas aeruginosa LESB65 sequence
# Score: 42.0
# E-value: 6.86003
# Identities: 27
# Alignment length: 31
#
#
# Title: gi|589320215|gb|CP006982.1| Pseudomonas aeruginosa LES400 sequence
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|589320215|gb|CP006982.1| Pseudomonas aeruginosa LES400 sequence
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|589320215|gb|CP006982.1| Pseudomonas aeruginosa LES400 sequence
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|589320215|gb|CP006982.1| Pseudomonas aeruginosa LES400 sequence
# Score: 44.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 34
#
#
# Title: gi|589320215|gb|CP006982.1| Pseudomonas aeruginosa LES400 sequence
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|589320215|gb|CP006982.1| Pseudomonas aeruginosa LES400 sequence
# Score: 42.0
# E-value: 6.86003
# Identities: 27
# Alignment length: 31
#
#
# Title: gi|589314341|gb|CP006981.1| Pseudomonas aeruginosa LESlike7 sequence
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|589314341|gb|CP006981.1| Pseudomonas aeruginosa LESlike7 sequence
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|589314341|gb|CP006981.1| Pseudomonas aeruginosa LESlike7 sequence
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|589314341|gb|CP006981.1| Pseudomonas aeruginosa LESlike7 sequence
# Score: 44.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 34
#
#
# Title: gi|589314341|gb|CP006981.1| Pseudomonas aeruginosa LESlike7 sequence
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|589308385|gb|CP006980.1| Pseudomonas aeruginosa LESlike5 sequence
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|589308385|gb|CP006980.1| Pseudomonas aeruginosa LESlike5 sequence
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|589308385|gb|CP006980.1| Pseudomonas aeruginosa LESlike5 sequence
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|589308385|gb|CP006980.1| Pseudomonas aeruginosa LESlike5 sequence
# Score: 44.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 34
#
#
# Title: gi|589308385|gb|CP006980.1| Pseudomonas aeruginosa LESlike5 sequence
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|589308385|gb|CP006980.1| Pseudomonas aeruginosa LESlike5 sequence
# Score: 42.0
# E-value: 6.86003
# Identities: 27
# Alignment length: 31
#
#
# Title: gi|566561164|gb|CP006937.1| Pseudomonas aeruginosa LES431, complete genome
# Score: 453.0
# E-value: 3.5348e-111
# Identities: 630
# Alignment length: 887
#
#
# Title: gi|566561164|gb|CP006937.1| Pseudomonas aeruginosa LES431, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|566561164|gb|CP006937.1| Pseudomonas aeruginosa LES431, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|566561164|gb|CP006937.1| Pseudomonas aeruginosa LES431, complete genome
# Score: 44.0
# E-value: 1.96543
# Identities: 30
# Alignment length: 34
#
#
# Title: gi|566561164|gb|CP006937.1| Pseudomonas aeruginosa LES431, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|566561164|gb|CP006937.1| Pseudomonas aeruginosa LES431, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 27
# Alignment length: 31
#
#
# Title: gi|576902775|gb|CP007147.1| Pseudomonas aeruginosa YL84, complete genome
# Score: 449.0
# E-value: 4.30627e-110
# Identities: 628
# Alignment length: 886
#
#
# Title: gi|576902775|gb|CP007147.1| Pseudomonas aeruginosa YL84, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|576902775|gb|CP007147.1| Pseudomonas aeruginosa YL84, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|975043142|gb|CP013989.1| Pseudomonas aeruginosa strain USDA-ARS-USMARC-41639 chromosome, complete genome
# Score: 448.0
# E-value: 4.30627e-110
# Identities: 629
# Alignment length: 887
#
#
# Title: gi|975043142|gb|CP013989.1| Pseudomonas aeruginosa strain USDA-ARS-USMARC-41639 chromosome, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|975043142|gb|CP013989.1| Pseudomonas aeruginosa strain USDA-ARS-USMARC-41639 chromosome, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|954630252|gb|CP013245.1| Pseudomonas aeruginosa strain VA-134 chromosome, complete genome
# Score: 448.0
# E-value: 4.30627e-110
# Identities: 629
# Alignment length: 887
#
#
# Title: gi|954630252|gb|CP013245.1| Pseudomonas aeruginosa strain VA-134 chromosome, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|954630252|gb|CP013245.1| Pseudomonas aeruginosa strain VA-134 chromosome, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|514245605|gb|CP006245.1| Pseudomonas aeruginosa RP73, complete genome
# Score: 448.0
# E-value: 4.30627e-110
# Identities: 629
# Alignment length: 887
#
#
# Title: gi|514245605|gb|CP006245.1| Pseudomonas aeruginosa RP73, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|514245605|gb|CP006245.1| Pseudomonas aeruginosa RP73, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|514245605|gb|CP006245.1| Pseudomonas aeruginosa RP73, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 33
# Alignment length: 41
#
#
# Title: gi|779731694|gb|CP010430.1| Geobacter sulfurreducens strain AM-1 genome
# Score: 444.0
# E-value: 5.24611e-109
# Identities: 633
# Alignment length: 901
#
#
# Title: gi|779731694|gb|CP010430.1| Geobacter sulfurreducens strain AM-1 genome
# Score: 43.0
# E-value: 6.86003
# Identities: 23
# Alignment length: 24
#
#
# Title: gi|982189197|gb|CP013993.1| Pseudomonas aeruginosa DHS01 chromosome, complete genome
# Score: 443.0
# E-value: 1.83107e-108
# Identities: 628
# Alignment length: 887
#
#
# Title: gi|982189197|gb|CP013993.1| Pseudomonas aeruginosa DHS01 chromosome, complete genome
# Score: 48.0
# E-value: 0.161332
# Identities: 27
# Alignment length: 29
#
#
# Title: gi|982189197|gb|CP013993.1| Pseudomonas aeruginosa DHS01 chromosome, complete genome
# Score: 47.0
# E-value: 0.563106
# Identities: 25
# Alignment length: 26
#
#
# Title: gi|982189197|gb|CP013993.1| Pseudomonas aeruginosa DHS01 chromosome, complete genome
# Score: 43.0
# E-value: 6.86003
# Identities: 29
# Alignment length: 34
#
#
# Title: gi|745831697|gb|CP006877.1| Rhizobium gallicum bv. gallicum R602sp strain R602 chromosome, complete genome
# Score: 438.0
# E-value: 2.2307e-107
# Identities: 535
# Alignment length: 734
#
#
# Title: gi|482529293|gb|CP005094.1| Azotobacter vinelandii CA, complete genome
# Score: 435.0
# E-value: 2.71755e-106
# Identities: 479
# Alignment length: 643
#
#
# Title: gi|482529293|gb|CP005094.1| Azotobacter vinelandii CA, complete genome
# Score: 45.0
# E-value: 1.96543
# Identities: 24
# Alignment length: 25
#
#
# Title: gi|482529293|gb|CP005094.1| Azotobacter vinelandii CA, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 24
# Alignment length: 26
#
#
# Title: gi|1248761407|gb|CP012621.1| Zobellella denitrificans strain F13-1 chromosome, complete genome
# Score: 424.0
# E-value: 1.40773e-103
# Identities: 537
# Alignment length: 750
#
#
# Title: gi|1248761407|gb|CP012621.1| Zobellella denitrificans strain F13-1 chromosome, complete genome
# Score: 44.0
# E-value: 1.96543
# Identities: 39
# Alignment length: 49
#
#
# Title: gi|1248761407|gb|CP012621.1| Zobellella denitrificans strain F13-1 chromosome, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 27
# Alignment length: 31
#
#
# Title: gi|567355861|gb|CP006979.1| Pseudomonas monteilii SB3101, complete genome
# Score: 418.0
# E-value: 5.98581e-102
# Identities: 477
# Alignment length: 647
#
#
# Title: gi|567355861|gb|CP006979.1| Pseudomonas monteilii SB3101, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 21
# Alignment length: 21
#
#
# Title: gi|567348216|gb|CP006978.1| Pseudomonas monteilii SB3078, complete genome
# Score: 418.0
# E-value: 5.98581e-102
# Identities: 477
# Alignment length: 647
#
#
# Title: gi|567348216|gb|CP006978.1| Pseudomonas monteilii SB3078, complete genome
# Score: 42.0
# E-value: 6.86003
# Identities: 21
# Alignment length: 21
#
#
# Title: gi|1057926126|gb|CP014262.1| Pseudomonas corrugata strain RM1-1-4 chromosome, complete genome
# Score: 417.0
# E-value: 2.08925e-101
# Identities: 506
# Alignment length: 698
#
#
# Title: gi|1057926126|gb|CP014262.1| Pseudomonas corrugata strain RM1-1-4 chromosome, complete genome
# Score: 49.0
# E-value: 0.161332
# Identities: 38
# Alignment length: 47
#
#
# Title: gi|1057926126|gb|CP014262.1| Pseudomonas corrugata strain RM1-1-4 chromosome, complete genome
# Score: 44.0
# E-value: 1.96543
# Identities: 39
# Alignment length: 49
#
#
# Results for DdrA:
# Title: gi|742984403|gb|CP010377.1| Enterobacter hormaechei subsp. hormaechei strain 34983, complete genome
# Score: 65.0
# E-value: 4.11226e-06
# Identities: 46
# Alignment length: 55
#
#
# Title: gi|924308395|gb|CP012257.1| Cronobacter universalis NCTC 9529, complete genome
# Score: 51.0
# E-value: 0.0259512
# Identities: 61
# Alignment length: 82
#
#
# Title: gi|119668705|emb|AM406670.1| Azoarcus olearius strain BH72 genome assembly
# Score: 51.0
# E-value: 0.0259512
# Identities: 46
# Alignment length: 57
#
#
# Title: gi|119668705|emb|AM406670.1| Azoarcus olearius strain BH72 genome assembly
# Score: 46.0
# E-value: 0.31615
# Identities: 26
# Alignment length: 28
#
#
# Title: gi|119668705|emb|AM406670.1| Azoarcus olearius strain BH72 genome assembly
# Score: 43.0
# E-value: 3.85149
# Identities: 52
# Alignment length: 72
#
#
# Title: gi|119668705|emb|AM406670.1| Azoarcus olearius strain BH72 genome assembly
# ...
# Score: 156.0
# E-value: 5.07359e-31
# Identities: 451
# Alignment length: 685
#
#
# Title: gi|973430823|gb|CP007518.2| Aeromonas hydrophila YL17, complete genome
# Score: 43.0
# E-value: 4.45448
# Identities: 29
# Alignment length: 34
#
#
# Title: gi|2265458965|emb|LR963141.1| Aeromonas hydrophila isolate T4 genome assembly, chromosome: 1
# Score: 236.0
# E-value: 9.78569e-53
# Identities: 448
# Alignment length: 659
#
#
# Title: gi|2265458965|emb|LR963141.1| Aeromonas hydrophila isolate T4 genome assembly, chromosome: 1
# Score: 149.0
# E-value: 7.52988e-29
# Identities: 448
# Alignment length: 682
#
#
# Title: gi|2265458965|emb|LR963141.1| Aeromonas hydrophila isolate T4 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 4.45448
# Identities: 29
# Alignment length: 34
#
#
# Title: gi|2265458965|emb|LR963141.1| Aeromonas hydrophila isolate T4 genome assembly, chromosome: 1
# Score: 42.0
# E-value: 4.45448
# Identities: 31
# Alignment length: 37
#
#
# Title: gi|975025465|gb|CP013965.1| Aeromonas hydrophila strain D4 chromosome, complete genome
# Score: 233.0
# E-value: 1.19214e-51
# Identities: 452
# Alignment length: 662
#
#
# Title: gi|975025465|gb|CP013965.1| Aeromonas hydrophila strain D4 chromosome, complete genome
# Score: 127.0
# E-value: 7.0524e-23
# Identities: 440
# Alignment length: 679
#
#
# Title: gi|958617326|gb|CP013178.1| Aeromonas hydrophila strain JBN2301 chromosome, complete genome
# Score: 233.0
# E-value: 1.19214e-51
# Identities: 452
# Alignment length: 662
#
#
# Title: gi|958617326|gb|CP013178.1| Aeromonas hydrophila strain JBN2301 chromosome, complete genome
# Score: 127.0
# E-value: 7.0524e-23
# Identities: 440
# Alignment length: 679
#
#
# Title: gi|827370414|gb|CP006870.1| Aeromonas hydrophila NJ-35, complete genome
# Score: 233.0
# E-value: 1.19214e-51
# Identities: 452
# Alignment length: 662
#
#
# Title: gi|827370414|gb|CP006870.1| Aeromonas hydrophila NJ-35, complete genome
# Score: 127.0
# E-value: 7.0524e-23
# Identities: 440
# Alignment length: 679
#
#
# Title: gi|785807861|gb|CP011100.1| Aeromonas hydrophila strain AH10, complete genome
# Score: 233.0
# E-value: 1.19214e-51
# Identities: 451
# Alignment length: 662
#
#
# Title: gi|785807861|gb|CP011100.1| Aeromonas hydrophila strain AH10, complete genome
# Score: 42.0
# E-value: 4.45448
# Identities: 31
# Alignment length: 37
#
#
# Title: gi|748231934|gb|CP006883.1| Aeromonas hydrophila J-1, complete genome
# Score: 233.0
# E-value: 1.19214e-51
# Identities: 452
# Alignment length: 662
#
#
# Title: gi|748231934|gb|CP006883.1| Aeromonas hydrophila J-1, complete genome
# Score: 127.0
# E-value: 7.0524e-23
# Identities: 440
# Alignment length: 679
#
#
# Title: gi|2265454226|emb|LR963138.1| Aeromonas hydrophila strain vAh ST251 genome assembly, chromosome: 1
# Score: 233.0
# E-value: 1.19214e-51
# Identities: 452
# Alignment length: 662
#
#
# Title: gi|2265454226|emb|LR963138.1| Aeromonas hydrophila strain vAh ST251 genome assembly, chromosome: 1
# Score: 127.0
# E-value: 7.0524e-23
# Identities: 440
# Alignment length: 679
#
#
# Title: gi|2265449258|emb|LR963135.1| Aeromonas hydrophila strain vAh ST251 genome assembly, chromosome: 1
# Score: 233.0
# E-value: 1.19214e-51
# Identities: 452
# Alignment length: 662
#
#
# Title: gi|2265449258|emb|LR963135.1| Aeromonas hydrophila strain vAh ST251 genome assembly, chromosome: 1
# Score: 127.0
# E-value: 7.0524e-23
# Identities: 440
# Alignment length: 679
#
#
# Title: gi|2265444577|emb|LR963132.1| Aeromonas hydrophila strain vAh ST251 genome assembly, chromosome: 1
# Score: 233.0
# E-value: 1.19214e-51
# Identities: 452
# Alignment length: 662
#
#
# Title: gi|2265444577|emb|LR963132.1| Aeromonas hydrophila strain vAh ST251 genome assembly, chromosome: 1
# Score: 127.0
# E-value: 7.0524e-23
# Identities: 440
# Alignment length: 679
#
#
# Title: gi|2265439653|emb|LR963129.1| Aeromonas hydrophila strain vAh ST251 genome assembly, chromosome: 1
# Score: 233.0
# E-value: 1.19214e-51
# Identities: 452
# Alignment length: 662
#
#
# Title: gi|2265439653|emb|LR963129.1| Aeromonas hydrophila strain vAh ST251 genome assembly, chromosome: 1
# Score: 127.0
# E-value: 7.0524e-23
# Identities: 440
# Alignment length: 679
#
#
# Title: gi|2265434934|emb|LR963127.1| Aeromonas hydrophila strain vAh ST251 genome assembly, chromosome: 1
# Score: 233.0
# E-value: 1.19214e-51
# Identities: 452
# Alignment length: 662
#
#
# Title: gi|2265434934|emb|LR963127.1| Aeromonas hydrophila strain vAh ST251 genome assembly, chromosome: 1
# Score: 127.0
# E-value: 7.0524e-23
# Identities: 440
# Alignment length: 679
#
#
# Title: gi|615567765|gb|CP007576.1| Aeromonas hydrophila pc104A, complete genome
# Score: 233.0
# E-value: 1.19214e-51
# Identities: 452
# Alignment length: 662
#
#
# Title: gi|615567765|gb|CP007576.1| Aeromonas hydrophila pc104A, complete genome
# Score: 127.0
# E-value: 7.0524e-23
# Identities: 440
# Alignment length: 679
#
#
# Title: gi|613730844|gb|CP007566.1| Aeromonas hydrophila AL09-71, complete genome
# Score: 233.0
# E-value: 1.19214e-51
# Identities: 452
# Alignment length: 662
#
#
# Title: gi|613730844|gb|CP007566.1| Aeromonas hydrophila AL09-71, complete genome
# Score: 127.0
# E-value: 7.0524e-23
# Identities: 440
# Alignment length: 679
#
#
# Title: gi|764079125|gb|CP010947.1| Aeromonas hydrophila strain AL06-06, complete genome
# Score: 231.0
# E-value: 4.16098e-51
# Identities: 447
# Alignment length: 659
#
#
# Title: gi|764079125|gb|CP010947.1| Aeromonas hydrophila strain AL06-06, complete genome
# Score: 141.0
# E-value: 1.11753e-26
# Identities: 448
# Alignment length: 685
#
#
# Title: gi|1006067808|gb|CP012504.1| Aeromonas veronii strain TH0426, complete genome
# Score: 228.0
# E-value: 1.45233e-50
# Identities: 443
# Alignment length: 657
#
#
# Title: gi|1006067808|gb|CP012504.1| Aeromonas veronii strain TH0426, complete genome
# Score: 122.0
# E-value: 8.59159e-22
# Identities: 435
# Alignment length: 668
#
#
# Title: gi|1006067808|gb|CP012504.1| Aeromonas veronii strain TH0426, complete genome
# Score: 42.0
# E-value: 4.45448
# Identities: 24
# Alignment length: 26
#
#
# Title: gi|1006067808|gb|CP012504.1| Aeromonas veronii strain TH0426, complete genome
# Score: 42.0
# E-value: 4.45448
# Identities: 31
# Alignment length: 37
#
#
# Title: gi|1024308492|gb|CP015448.1| Aeromonas veronii strain CB51 chromosome, complete genome
# Score: 224.0
# E-value: 1.76929e-49
# Identities: 440
# Alignment length: 656
#
#
# Title: gi|1024308492|gb|CP015448.1| Aeromonas veronii strain CB51 chromosome, complete genome
# Score: 42.0
# E-value: 4.45448
# Identities: 31
# Alignment length: 37
#
#
# Title: gi|1028492573|gb|CP015137.1| Dickeya solani IPO 2222 chromosome, complete genome
# Score: 223.0
# E-value: 6.17544e-49
# Identities: 440
# Alignment length: 649
#
#
# Title: gi|2265430172|emb|LR963122.1| Aeromonas dhakensis isolate TN4 genome assembly, chromosome: 1
# Score: 218.0
# E-value: 7.52323e-48
# Identities: 448
# Alignment length: 662
#
#
# Title: gi|2265430172|emb|LR963122.1| Aeromonas dhakensis isolate TN4 genome assembly, chromosome: 1
# Score: 161.0
# E-value: 4.16466e-32
# Identities: 452
# Alignment length: 685
#
#
# Title: gi|2265430172|emb|LR963122.1| Aeromonas dhakensis isolate TN4 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 4.45448
# Identities: 29
# Alignment length: 34
#
#
# Title: gi|2265425554|emb|LR963117.1| Aeromonas dhakensis isolate TN5 genome assembly, chromosome: 1
# Score: 218.0
# E-value: 7.52323e-48
# Identities: 448
# Alignment length: 662
#
#
# Title: gi|2265425554|emb|LR963117.1| Aeromonas dhakensis isolate TN5 genome assembly, chromosome: 1
# Score: 161.0
# E-value: 4.16466e-32
# Identities: 452
# Alignment length: 685
#
#
# Title: gi|2265425554|emb|LR963117.1| Aeromonas dhakensis isolate TN5 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 4.45448
# Identities: 29
# Alignment length: 34
#
#
# Title: gi|2265420415|emb|LR963112.1| Aeromonas dhakensis isolate TN3 genome assembly, chromosome: 1
# Score: 218.0
# E-value: 7.52323e-48
# Identities: 448
# Alignment length: 662
#
#
# Title: gi|2265420415|emb|LR963112.1| Aeromonas dhakensis isolate TN3 genome assembly, chromosome: 1
# Score: 161.0
# E-value: 4.16466e-32
# Identities: 452
# Alignment length: 685
#
#
# Title: gi|2265420415|emb|LR963112.1| Aeromonas dhakensis isolate TN3 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 4.45448
# Identities: 29
# Alignment length: 34
#
#
# Title: gi|2265415584|emb|LR963107.1| Aeromonas dhakensis isolate TN49 genome assembly, chromosome: 1
# Score: 218.0
# E-value: 7.52323e-48
# Identities: 448
# Alignment length: 662
#
#
# Title: gi|2265415584|emb|LR963107.1| Aeromonas dhakensis isolate TN49 genome assembly, chromosome: 1
# Score: 161.0
# E-value: 4.16466e-32
# Identities: 452
# Alignment length: 685
#
#
# Title: gi|2265415584|emb|LR963107.1| Aeromonas dhakensis isolate TN49 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 4.45448
# Identities: 29
# Alignment length: 34
#
#
# Title: gi|2265410592|emb|LR963104.1| Aeromonas dhakensis isolate TN14 genome assembly, chromosome: 1
# Score: 218.0
# E-value: 7.52323e-48
# Identities: 448
# Alignment length: 662
#
#
# Title: gi|2265410592|emb|LR963104.1| Aeromonas dhakensis isolate TN14 genome assembly, chromosome: 1
# Score: 161.0
# E-value: 4.16466e-32
# Identities: 452
# Alignment length: 685
#
#
# Title: gi|2265410592|emb|LR963104.1| Aeromonas dhakensis isolate TN14 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 4.45448
# Identities: 29
# Alignment length: 34
#
#
# Title: gi|2265405416|emb|LR963099.1| Aeromonas dhakensis isolate TN10 genome assembly, chromosome: 1
# Score: 218.0
# E-value: 7.52323e-48
# Identities: 448
# Alignment length: 662
#
#
# Title: gi|2265405416|emb|LR963099.1| Aeromonas dhakensis isolate TN10 genome assembly, chromosome: 1
# Score: 161.0
# E-value: 4.16466e-32
# Identities: 452
# Alignment length: 685
#
#
# Title: gi|2265405416|emb|LR963099.1| Aeromonas dhakensis isolate TN10 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 4.45448
# Identities: 29
# Alignment length: 34
#
#
# Title: gi|2265400372|emb|LR963094.1| Aeromonas dhakensis isolate TN50 genome assembly, chromosome: 1
# Score: 218.0
# E-value: 7.52323e-48
# Identities: 448
# Alignment length: 662
#
#
# Title: gi|2265400372|emb|LR963094.1| Aeromonas dhakensis isolate TN50 genome assembly, chromosome: 1
# Score: 161.0
# E-value: 4.16466e-32
# Identities: 452
# Alignment length: 685
#
#
# Title: gi|2265400372|emb|LR963094.1| Aeromonas dhakensis isolate TN50 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 4.45448
# Identities: 29
# Alignment length: 34
#
#
# Title: gi|2265395661|emb|LR963089.1| Aeromonas dhakensis isolate TN11 genome assembly, chromosome: 1
# Score: 218.0
# E-value: 7.52323e-48
# Identities: 448
# Alignment length: 662
#
#
# Title: gi|2265395661|emb|LR963089.1| Aeromonas dhakensis isolate TN11 genome assembly, chromosome: 1
# Score: 161.0
# E-value: 4.16466e-32
# Identities: 452
# Alignment length: 685
#
#
# Title: gi|2265395661|emb|LR963089.1| Aeromonas dhakensis isolate TN11 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 4.45448
# Identities: 29
# Alignment length: 34
#
#
# Title: gi|2265390828|emb|LR963084.1| Aeromonas dhakensis isolate TN59 genome assembly, chromosome: 1
# Score: 218.0
# E-value: 7.52323e-48
# Identities: 448
# Alignment length: 662
#
#
# Title: gi|2265390828|emb|LR963084.1| Aeromonas dhakensis isolate TN59 genome assembly, chromosome: 1
# Score: 161.0
# E-value: 4.16466e-32
# Identities: 452
# Alignment length: 685
#
#
# Title: gi|2265390828|emb|LR963084.1| Aeromonas dhakensis isolate TN59 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 4.45448
# Identities: 29
# Alignment length: 34
#
#
# Title: gi|2265386260|emb|LR963079.1| Aeromonas dhakensis isolate TN45 genome assembly, chromosome: 1
# Score: 218.0
# E-value: 7.52323e-48
# Identities: 448
# Alignment length: 662
#
#
# Title: gi|2265386260|emb|LR963079.1| Aeromonas dhakensis isolate TN45 genome assembly, chromosome: 1
# Score: 161.0
# E-value: 4.16466e-32
# Identities: 452
# Alignment length: 685
#
#
# Title: gi|2265386260|emb|LR963079.1| Aeromonas dhakensis isolate TN45 genome assembly, chromosome: 1
# Score: 43.0
# E-value: 4.45448
# Identities: 29
# Alignment length: 34
#
#
# Title: gi|1024268833|gb|CP014774.1| Aeromonas veronii strain AVNIH1, complete genome
# Score: 209.0
# E-value: 3.89713e-45
# Identities: 437
# Alignment length: 656
#
#
# Title: gi|1024268833|gb|CP014774.1| Aeromonas veronii strain AVNIH1, complete genome
# Score: 42.0
# E-value: 4.45448
# Identities: 31
# Alignment length: 37
#
#
# Title: gi|690285043|gb|CP009460.1| Dickeya fangzhongdai strain ND14b chromosome, complete genome
# Score: 202.0
# E-value: 1.6571e-43
# Identities: 445
# Alignment length: 662
#
#
# Title: gi|1248761407|gb|CP012621.1| Zobellella denitrificans strain F13-1 chromosome, complete genome
# Score: 199.0
# E-value: 2.01876e-42
# Identities: 462
# Alignment length: 689
#
#
# Title: gi|828966150|gb|CP011642.1| Serratia marcescens strain CAV1492, complete genome
# Score: 177.0
# E-value: 1.89075e-36
# Identities: 440
# Alignment length: 663
#
#
# Title: gi|926475601|gb|CP012639.1| Serratia marcescens strain RSC-14, complete genome
# Score: 171.0
# E-value: 8.03968e-35
# Identities: 454
# Alignment length: 692
#
#
# Title: gi|690280870|gb|CP009459.1| Cedecea neteri strain ND14a, complete genome
# Score: 170.0
# E-value: 8.03968e-35
# Identities: 451
# Alignment length: 675
#
#
# Title: gi|690280870|gb|CP009459.1| Cedecea neteri strain ND14a, complete genome
# Score: 59.0
# E-value: 0.000202233
# Identities: 43
# Alignment length: 52
#
#
# Title: gi|690280870|gb|CP009459.1| Cedecea neteri strain ND14a, complete genome
# Score: 50.0
# E-value: 0.0300141
# Identities: 43
# Alignment length: 55
#
#
# Title: gi|924328937|gb|CP012266.1| Cronobacter dublinensis subsp. dublinensis LMG 23823, complete genome
# Score: 169.0
# E-value: 2.80612e-34
# Identities: 436
# Alignment length: 656
#
#
# Title: gi|924328937|gb|CP012266.1| Cronobacter dublinensis subsp. dublinensis LMG 23823, complete genome
# Score: 47.0
# E-value: 0.365646
# Identities: 28
# Alignment length: 31
#
#
# Title: gi|909893832|gb|CP012167.1| Enterobacter hormaechei subsp. steigerwaltii strain 34998, complete genome
# Score: 168.0
# E-value: 2.80612e-34
# Identities: 438
# Alignment length: 657
#
#
# Title: gi|744784319|gb|CP006929.1| Dickeya zeae EC1, complete genome
# Score: 164.0
# E-value: 3.41856e-33
# Identities: 428
# Alignment length: 648
#
#
# Title: gi|1127556898|gb|CP010584.1| Serratia marcescens strain AS1 genome
# Score: 162.0
# E-value: 1.19319e-32
# Identities: 436
# Alignment length: 663
#
#
# Title: gi|689262542|gb|CP009451.1| Cedecea neteri strain SSMD04, complete genome
# Score: 160.0
# E-value: 4.16466e-32
# Identities: 428
# Alignment length: 642
#
#
# Title: gi|689262542|gb|CP009451.1| Cedecea neteri strain SSMD04, complete genome
# Score: 68.0
# E-value: 3.90402e-07
# Identities: 149
# Alignment length: 222
#
#
# Title: gi|689262542|gb|CP009451.1| Cedecea neteri strain SSMD04, complete genome
# Score: 45.0
# E-value: 1.27623
# Identities: 42
# Alignment length: 55
#
#
# Title: gi|1043694348|gb|CP011662.1| Enterobacter hormaechei strain CAV1176, complete genome
# Score: 158.0
# E-value: 1.45361e-31
# Identities: 436
# Alignment length: 657
#
#
# Title: gi|828977725|gb|CP011650.1| Enterobacter hormaechei strain CAV1669, complete genome
# Score: 158.0
# E-value: 1.45361e-31
# Identities: 436
# Alignment length: 657
#
#
# Title: gi|828916888|gb|CP011584.1| Enterobacter hormaechei strain CAV1668, complete genome
# Score: 158.0
# E-value: 1.45361e-31
# Identities: 436
# Alignment length: 657
#
#
# Title: gi|828911693|gb|CP011581.1| Enterobacter hormaechei strain CAV1411, complete genome
# Score: 158.0
# E-value: 1.45361e-31
# Identities: 436
# Alignment length: 657
#
#
# Title: gi|689257448|gb|CP009450.1| Pluralibacter gergoviae strain FB2, complete genome
# Score: 153.0
# E-value: 6.1809e-30
# Identities: 462
# Alignment length: 697
#
#
# Title: gi|689257448|gb|CP009450.1| Pluralibacter gergoviae strain FB2, complete genome
# Score: 43.0
# E-value: 4.45448
# Identities: 37
# Alignment length: 45
#
#
# Title: gi|723239679|gb|CP009866.1| Pantoea sp. PSNIH2, complete genome
# Score: 152.0
# E-value: 6.1809e-30
# Identities: 436
# Alignment length: 662
#
#
# Title: gi|908276372|gb|CP010376.2| Enterobacter hormaechei subsp. steigerwaltii strain 34977, complete genome
# Score: 148.0
# E-value: 7.52988e-29
# Identities: 434
# Alignment length: 657
#
#
# Title: gi|834903891|gb|CP011364.1| Edwardsiella sp. EA181011, complete genome
# Score: 140.0
# E-value: 1.11753e-26
# Identities: 443
# Alignment length: 682
#
#
# Title: gi|984699415|gb|CP014207.1| Pantoea ananatis strain R100, complete genome
# Score: 136.0
# E-value: 1.36143e-25
# Identities: 163
# Alignment length: 225
#
#
# Title: gi|984699415|gb|CP014207.1| Pantoea ananatis strain R100, complete genome
# Score: 55.0
# E-value: 0.00246371
# Identities: 116
# Alignment length: 175
